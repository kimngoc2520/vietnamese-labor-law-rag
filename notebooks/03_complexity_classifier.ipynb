# %% [markdown]
# # Complexity Classifier
# Inspect adaptive retrieval depth for representative queries.

# %%
from src.retrieval.adaptive import adaptive_k

[adaptive_k(score) for score in (0.0, 0.5, 1.0)]
