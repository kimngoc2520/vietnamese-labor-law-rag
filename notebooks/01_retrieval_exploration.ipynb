# %% [markdown]
# # Retrieval Exploration
# Explore dense, sparse, and hybrid retrieval results.

# %%
from src.retrieval.complexity import estimate_complexity

query = 'What is adaptive retrieval?'
estimate_complexity(query)
